# %% [markdown]
# # Pandas Cont.
# ## loading external data (csv,xml,....)

# %%
import pandas as pd

df2 = pd.read_csv('students.csv',index_col = 0)
df2
# Out:
#         Age  Maths  English  Science
# Name
# Alex   10.0   35.0     40.0       89
# Bob    12.0   34.0     50.0       67
# Dave   12.0   40.0     50.0       60
# Ans    13.0   40.0     50.0       50
# Ans    13.0   40.0     50.0       50
# Jerry  14.0   43.0     45.0       50
# Sam    10.0   40.0     56.0       60
# Tim    12.0   45.0     55.0       50
# Amy    13.0   40.0     45.0       50

# %%
df2 = pd.read_csv('students2.csv',index_col = 0,keep_default_na=False)
df2
# Out:
#         Age  Maths  English  Science
# Name
# Alex   10.0   35.0     40.0       89
# Bob    12.0   34.0     50.0       67
#        12.0   40.0     50.0       60
# Ans    13.0   40.0     50.0       50
# Ans    13.0   40.0     50.0       50
# Jerry  14.0   43.0     45.0       50
# Sam    10.0   40.0     56.0       60
# Tim    12.0   45.0     55.0       50
# Amy    13.0   40.0     45.0       50

# %%
df2
# Out:
#         Age  Maths  English  Science
# Name
# Alex   10.0   35.0     40.0       89
# Bob    12.0   34.0     50.0       67
#        12.0   40.0     50.0       60
# Ans    13.0   40.0     50.0       50
# Ans    13.0   40.0     50.0       50
# Jerry  14.0   43.0     45.0       50
# Sam    10.0   40.0     56.0       60
# Tim    12.0   45.0     55.0       50
# Amy    13.0   40.0     45.0       50

# %%
df2.to_excel('students3.xlsx')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df2.to_excel('students3.xlsx')
#
# File F:\Python 3.11\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File F:\Python 3.11\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
pip install openpyxl
# Out:
# ...
#      -------------------------------------- 250.0/250.0 kB 2.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df2.to_excel('students3.xlsx')

# %%
df3 = pd.read_excel('students3.xlsx')
df3
# Out:
#     Name  Age  Maths  English  Science
# 0   Alex   10     35       40       89
# 1    Bob   12     34       50       67
# 2    NaN   12     40       50       60
# 3    Ans   13     40       50       50
# 4    Ans   13     40       50       50
# 5  Jerry   14     43       45       50
# 6    Sam   10     40       56       60
# 7    Tim   12     45       55       50
# 8    Amy   13     40       45       50

# %%
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass         Lname  \
# 0              1         0       3        Braund
# 1              2         1       1       Cumings
# 2              3         1       3     Heikkinen
# 3              4         1       1      Futrelle
# 4              5         0       3         Allen
# ..           ...       ...     ...           ...
# 151          152         1       1         Pears
# 152          153         0       3           Meo
# 153          154         0       3  van Billiard
# 154          155         0       3         Olsen
# 155          156         0       1      Williams
#
#                                             Name     Sex   Age  SibSp  Parch  \
# 0                                Mr. Owen Harris    male  22.0      1      0
# 1     Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1      0
# 2                                    Miss. Laina  female  26.0      0      0
# ...

# %%
player_data = pd.read_csv('Player Dataset.csv')
player_data
# Out:
#     S No       Player Name  Jersey No  Matches played         Role  Runs   \
# 0      1  Sachin Tendulkar         10             463      Batsman  18426
# 1      2       Virat Kohli         18             248      Batsman  11867
# 2      3          MS Dhoni          7             350  Batsman, WK  10773
# 3      4      Rohit Sharma         45             224      Batsman   9115
# 4      5            Sehwag         46             251      Batsman   8273
# 5      6           Gambhir          5             147      Batsman   5238
# 6      7            Yuvraj         12             304  All-rounder   8701
# 7      8          R Jadeja          8             165  All-rounder   2296
# 8      9       Zaheer Khan         34             200       Bowler    792
# 9     10           H Singh          3             236       Bowler   1237
# 10    11            Bumrah         93              64       Bowler     39
# 11    12           M Shami         11              77       Bowler    145
# ...

# %%
player_data.head() # first 5 data
# Out:
#    S No       Player Name  Jersey No  Matches played         Role  Runs   \
# 0     1  Sachin Tendulkar         10             463      Batsman  18426
# 1     2       Virat Kohli         18             248      Batsman  11867
# 2     3          MS Dhoni          7             350  Batsman, WK  10773
# 3     4      Rohit Sharma         45             224      Batsman   9115
# 4     5            Sehwag         46             251      Batsman   8273
#
#    Batting Avg  Highest score Wickets Bowling Avg Best bowling
# 0        44.83            200     154       44.48          5/32
# 1        59.34            183       4      166.25          1/15
# 2        50.58            183       1          31          1/14
# 3        49.27            267       8       64.38          2/27
# 4        35.04            219      96       40.14           4/6

# %%
player_data.tail() # last 5 data
# Out:
#     S No     Player Name  Jersey No  Matches played         Role  Runs   \
# 20    21    Rahul Dravid         19             344      Batsman  10889
# 21    22  Shikhar Dhawan         42             136      Batsman   5688
# 22    23    Prithvi Shaw        100               3      Batsman     84
# 23    24   Parthiv Patel         42              38   Batsman,WK    736
# 24    25    Irfan Pathan         56             120  All-rounder   1544
#
#     Batting Avg  Highest score Wickets Bowling Avg Best bowling
# 20        39.16            153       4        42.5          2/43
# 21        45.14            143     ---        ----          ----
# 22        28.00             40     ---        ----          ----
# 23        23.74             95     ---        ----          ----
# 24        23.39             83     173       29.72          5/27

# %%
player_data.head(10) # first 10 data
# Out:
#    S No       Player Name  Jersey No  Matches played         Role  Runs   \
# 0     1  Sachin Tendulkar         10             463      Batsman  18426
# 1     2       Virat Kohli         18             248      Batsman  11867
# 2     3          MS Dhoni          7             350  Batsman, WK  10773
# 3     4      Rohit Sharma         45             224      Batsman   9115
# 4     5            Sehwag         46             251      Batsman   8273
# 5     6           Gambhir          5             147      Batsman   5238
# 6     7            Yuvraj         12             304  All-rounder   8701
# 7     8          R Jadeja          8             165  All-rounder   2296
# 8     9       Zaheer Khan         34             200       Bowler    792
# 9    10           H Singh          3             236       Bowler   1237
#
#    Batting Avg  Highest score Wickets Bowling Avg Best bowling
# 0        44.83            200     154       44.48          5/32
# ...

# %%
player_data.tail(7) # Last 7 data
# Out:
#     S No     Player Name  Jersey No  Matches played         Role  Runs   \
# 18    19   Robin Uthappa          6              46      Batsman    934
# 19    20   Ambati Rayudu          5              55      Batsman   1694
# 20    21    Rahul Dravid         19             344      Batsman  10889
# 21    22  Shikhar Dhawan         42             136      Batsman   5688
# 22    23    Prithvi Shaw        100               3      Batsman     84
# 23    24   Parthiv Patel         42              38   Batsman,WK    736
# 24    25    Irfan Pathan         56             120  All-rounder   1544
#
#     Batting Avg  Highest score Wickets Bowling Avg Best bowling
# 18        25.94             86    ----       -----         -----
# 19        47.05            124       3       41.33           1/5
# 20        39.16            153       4        42.5          2/43
# 21        45.14            143     ---        ----          ----
# 22        28.00             40     ---        ----          ----
# ...

# %%
player_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S No            25 non-null     int64
#  1   Player Name     25 non-null     object
#  2   Jersey No       25 non-null     int64
#  3   Matches played  25 non-null     int64
#  4   Role            25 non-null     object
#  5   Runs            25 non-null     int64
#  6   Batting Avg     25 non-null     float64
#  7   Highest score   25 non-null     int64
#  8   Wickets         25 non-null     object
#  9   Bowling Avg     25 non-null     object
#  10  Best bowling    25 non-null     object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 2.3+ KB

# %%
player_data.set_index('S No')
# Out:
#            Player Name  Jersey No  Matches played         Role  Runs   \
# S No
# 1     Sachin Tendulkar         10             463      Batsman  18426
# 2          Virat Kohli         18             248      Batsman  11867
# 3             MS Dhoni          7             350  Batsman, WK  10773
# 4         Rohit Sharma         45             224      Batsman   9115
# 5               Sehwag         46             251      Batsman   8273
# 6              Gambhir          5             147      Batsman   5238
# 7               Yuvraj         12             304  All-rounder   8701
# 8             R Jadeja          8             165  All-rounder   2296
# 9          Zaheer Khan         34             200       Bowler    792
# 10             H Singh          3             236       Bowler   1237
# 11              Bumrah         93              64       Bowler     39
# 12             M Shami         11              77       Bowler    145
# ...

# %%
player_data.set_index('S No',inplace = True)

# %%
player_data
# Out:
#            Player Name  Jersey No  Matches played         Role  Runs   \
# S No
# 1     Sachin Tendulkar         10             463      Batsman  18426
# 2          Virat Kohli         18             248      Batsman  11867
# 3             MS Dhoni          7             350  Batsman, WK  10773
# 4         Rohit Sharma         45             224      Batsman   9115
# 5               Sehwag         46             251      Batsman   8273
# 6              Gambhir          5             147      Batsman   5238
# 7               Yuvraj         12             304  All-rounder   8701
# 8             R Jadeja          8             165  All-rounder   2296
# 9          Zaheer Khan         34             200       Bowler    792
# 10             H Singh          3             236       Bowler   1237
# 11              Bumrah         93              64       Bowler     39
# 12             M Shami         11              77       Bowler    145
# ...

# %%
# total runs 

player_data['Highest score'].sum()
# Out:
# 2650

# %%
player_data['Runs '].sum()
# Out:
# 103361

# %%
player_data['Runs '].std
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.std of S No
# 1     18426
# 2     11867
# 3     10773
# 4      9115
# 5      8273
# 6      5238
# 7      8701
# 8      2296
# 9       792
# 10     1237
# 11       39
# 12      145
# 13      675
# 14      118
# 15        5
# 16      951
# 17     1389
# 18     1752
# 19      934
# 20     1694
# 21    10889
# 22     5688
# 23       84
# 24      736
# 25     1544
# Name: Runs , dtype: int64>

# %%
# gorup based on roles

player_data.groupby('Role').value_counts
# Out:
# <bound method DataFrameGroupBy.value_counts of <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000020D8DA06990>>

# %%
player_data.groupby('Role')["Runs "].sum()
# Out:
# Role
# All-rounder    13492
# All_rounder     1389
# Batsman        72208
# Batsman, WK    10773
# Batsman,WK      2488
# Bowler          3011
# Name: Runs , dtype: int64

# %%
player_data.groupby('Role')['Matches played'].max()
# Out:
# Role
# All-rounder    304
# All_rounder     73
# Batsman        463
# Batsman, WK    350
# Batsman,WK      94
# Bowler         236
# Name: Matches played, dtype: int64

# %%
len(player_data.groupby('Role')['Matches played'])
# Out:
# 6

# %%
len(player_data.groupby('Role'))
# Out:
# 6

# %%
player_data['Role'].value_counts()
# Out:
# Batsman        10
# Bowler          7
# All-rounder     4
# Batsman,WK      2
# Batsman, WK     1
# All_rounder     1
# Name: Role, dtype: int64

# %%
player_data[player_data['Runs ']>10000]
# Out:
#            Player Name  Jersey No  Matches played         Role  Runs   \
# S No
# 1     Sachin Tendulkar         10             463      Batsman  18426
# 2          Virat Kohli         18             248      Batsman  11867
# 3             MS Dhoni          7             350  Batsman, WK  10773
# 21        Rahul Dravid         19             344      Batsman  10889
#
#       Batting Avg  Highest score Wickets Bowling Avg Best bowling
# S No
# 1           44.83            200     154       44.48          5/32
# 2           59.34            183       4      166.25          1/15
# 3           50.58            183       1          31          1/14
# 21          39.16            153       4        42.5          2/43

# %%
player_data['Runs ']>10000
# Out:
# S No
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# Name: Runs , dtype: bool

# %%
type(player_data['Player Name'][1])
# Out:
# str

# %%
player_data[player_data['Runs ']>10000][['Player Name','Runs ']]
# Out:
#            Player Name  Runs
# S No
# 1     Sachin Tendulkar  18426
# 2          Virat Kohli  11867
# 3             MS Dhoni  10773
# 21        Rahul Dravid  10889

# %%
player_data.isna() # cheking None values
# Out:
#       Player Name  Jersey No  Matches played   Role  Runs   Batting Avg  \
# S No
# 1           False      False           False  False  False        False
# 2           False      False           False  False  False        False
# 3           False      False           False  False  False        False
# 4           False      False           False  False  False        False
# 5           False      False           False  False  False        False
# 6           False      False           False  False  False        False
# 7           False      False           False  False  False        False
# 8           False      False           False  False  False        False
# 9           False      False           False  False  False        False
# 10          False      False           False  False  False        False
# 11          False      False           False  False  False        False
# 12          False      False           False  False  False        False
# ...

# %%
player_data = pd.read_csv('Player Dataset.csv')

# %%
player_data.isna() # cheking None values
# Out:
#      S No  Player Name  Jersey No  Matches played   Role  Runs   Batting Avg  \
# 0   False        False      False           False  False  False        False
# 1   False        False      False           False  False  False        False
# 2   False        False      False           False  False  False        False
# 3   False        False      False           False  False  False        False
# 4   False        False      False           False  False  False        False
# 5   False        False      False           False  False  False        False
# 6   False        False      False           False  False  False        False
# 7   False        False      False           False  False  False        False
# 8   False        False      False           False  False  False        False
# 9   False        False      False           False  False  False        False
# 10  False        False      False           False  False  False        False
# ...

# %%
# dropna null values removing
player_data.dropna()
# Out:
#     S No       Player Name  Jersey No  Matches played         Role  Runs   \
# 0      1  Sachin Tendulkar         10             463      Batsman  18426
# 1      2       Virat Kohli         18             248      Batsman  11867
# 2      3          MS Dhoni          7             350  Batsman, WK  10773
# 3      4      Rohit Sharma         45             224      Batsman   9115
# 4      5            Sehwag         46             251      Batsman   8273
# 5      6           Gambhir          5             147      Batsman   5238
# 6      7            Yuvraj         12             304  All-rounder   8701
# 7      8          R Jadeja          8             165  All-rounder   2296
# 8      9       Zaheer Khan         34             200       Bowler    792
# 9     10           H Singh          3             236       Bowler   1237
# 10    11            Bumrah         93              64       Bowler     39
# 11    12           M Shami         11              77       Bowler    145
# ...

# %%
player_data.dropna(inplace=True) # removing permanently

# %%
player_data
# Out:
#     S No       Player Name  Jersey No  Matches played         Role  Runs   \
# 0      1  Sachin Tendulkar         10             463      Batsman  18426
# 1      2       Virat Kohli         18             248      Batsman  11867
# 2      3          MS Dhoni          7             350  Batsman, WK  10773
# 3      4      Rohit Sharma         45             224      Batsman   9115
# 4      5            Sehwag         46             251      Batsman   8273
# 5      6           Gambhir          5             147      Batsman   5238
# 6      7            Yuvraj         12             304  All-rounder   8701
# 7      8          R Jadeja          8             165  All-rounder   2296
# 8      9       Zaheer Khan         34             200       Bowler    792
# 9     10           H Singh          3             236       Bowler   1237
# 10    11            Bumrah         93              64       Bowler     39
# 11    12           M Shami         11              77       Bowler    145
# ...

# %%
# statistics 

player_data['Runs '].mean()
# Out:
# 4206.04347826087

# %%
player_data['Runs '].median()
# Out:
# 1544.0

# %%
player_data['Role'].mode()
# Out:
# 0    Batsman
# Name: Role, dtype: object

# %%
player_data['Runs '].std()
# Out:
# 5145.073075532472

# %%
player_data['Runs '].count() # number of rows
# Out:
# 23

# %%
player_data['Runs '].max()
# Out:
# 18426

# %%
player_data['Runs '].min()
# Out:
# 5

# %%
player_data.describe()
# Out:
#             S No   Jersey No  Matches played         Runs   Batting Avg  \
# count  23.000000   23.000000       23.000000     23.000000    23.000000
# mean   12.347826   33.782609      161.869565   4206.043478    29.536522
# std     7.302607   31.820457      122.076840   5145.073076    16.044433
# min     1.000000    3.000000        3.000000      5.000000     2.500000
# 25%     6.500000    9.000000       62.000000    705.500000    14.685000
# 50%    12.000000   21.000000      120.000000   1544.000000    30.200000
# 75%    17.500000   45.500000      242.000000   8487.000000    40.885000
# max    25.000000  100.000000      463.000000  18426.000000    59.340000
#
#        Highest score
# count      23.000000
# mean      105.260870
# std        72.821836
# min         3.000000
# 25%        44.500000
# 50%        87.000000
# 75%       151.500000
# max       267.000000

# %%
player_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 0 to 24
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S No            23 non-null     int64
#  1   Player Name     23 non-null     object
#  2   Jersey No       23 non-null     int64
#  3   Matches played  23 non-null     int64
#  4   Role            23 non-null     object
#  5   Runs            23 non-null     int64
#  6   Batting Avg     23 non-null     float64
#  7   Highest score   23 non-null     int64
#  8   Wickets         23 non-null     object
#  9   Bowling Avg     23 non-null     object
#  10  Best bowling    23 non-null     object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 2.2+ KB
